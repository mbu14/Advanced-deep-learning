# %%
import tensorflow as tf
from tensorflow.keras import layers, models

import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms

import wandb
from wandb.integration.keras import WandbCallback, WandbEvalCallback, WandbMetricsLogger
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1774897454.543382   10247 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # 01 Task

# %% [markdown]
# # With tensorflow

# %%
# load data
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

print("Train:", x_train.shape)
print("Test:", x_test.shape)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/datasets/cifar.py:18: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   d = cPickle.load(f, encoding="bytes")
# Train: (50000, 32, 32, 3)
# Test: (10000, 32, 32, 3)

# %%
wandb.init(
    project="cnn-image-classification",
    config={
        "epochs": 50,
        "batch_size": 32,
        "learning_rate": 0.0001,
        "architecture": "CNN",
        "activation": "tanh"
    }
)
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# wandb: Currently logged in as: linneaborg03 (linneaborg03-lule-university-of-technology) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.25.1
# Run data is saved locally in <code>/wandb/run-20260330_210517-ehcodint</code>
# Syncing run <strong><a href='https://wandb.ai/linneaborg03-lule-university-of-technology/cnn-image-classification/runs/ehcodint' target="_blank">charmed-pyramid-6</a></strong> to <a href='https://wandb.ai/linneaborg03-lule-university-of-technology/cnn-image-classification' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/linneaborg03-lule-university-of-technology/cnn-image-classification' target="_blank">https://wandb.ai/linneaborg03-lule-university-of-technology/cnn-image-classification</a>
#  View run at <a href='https://wandb.ai/linneaborg03-lule-university-of-technology/cnn-image-classification/runs/ehcodint' target="_blank">https://wandb.ai/linneaborg03-lule-university-of-technology/cnn-image-classification/runs/ehcodint</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/linneaborg03-lule-university-of-technology/cnn-image-classification/runs/ehcodint?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %%
x_train = x_train / 255.0
x_test = x_test / 255.0 #To make the pixels range between 0 and 1  instead of 0 and 255

# %% [markdown]
# ### first version

# %%
wandb.init(
    project="cnn-project",
    config={
        "epochs": 50,
        "batch_size": 32
    }
)

config = wandb.config
# Out:
# Finishing previous runs because reinit is set to 'default'.
#  View run <strong style="color:#cdcd00">charmed-pyramid-6</strong> at: <a href='https://wandb.ai/linneaborg03-lule-university-of-technology/cnn-image-classification/runs/ehcodint' target="_blank">https://wandb.ai/linneaborg03-lule-university-of-technology/cnn-image-classification/runs/ehcodint</a><br> View project at: <a href='https://wandb.ai/linneaborg03-lule-university-of-technology/cnn-image-classification' target="_blank">https://wandb.ai/linneaborg03-lule-university-of-technology/cnn-image-classification</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code></code>
# Tracking run with wandb version 0.25.1
# Run data is saved locally in <code>/wandb/run-20260330_210530-97w1tll5</code>
# Syncing run <strong><a href='https://wandb.ai/linneaborg03-lule-university-of-technology/cnn-project/runs/97w1tll5' target="_blank">easy-shadow-5</a></strong> to <a href='https://wandb.ai/linneaborg03-lule-university-of-technology/cnn-project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/linneaborg03-lule-university-of-technology/cnn-project' target="_blank">https://wandb.ai/linneaborg03-lule-university-of-technology/cnn-project</a>
#  View run at <a href='https://wandb.ai/linneaborg03-lule-university-of-technology/cnn-project/runs/97w1tll5' target="_blank">https://wandb.ai/linneaborg03-lule-university-of-technology/cnn-project/runs/97w1tll5</a>

# %%
model = models.Sequential([

    layers.Conv2D(32, (3,3), input_shape=(32,32,3)),
    layers.LeakyReLU(),
    layers.MaxPooling2D((2,2)),

    layers.Conv2D(64, (3,3)),
    layers.LeakyReLU(),
    layers.MaxPooling2D((2,2)),

    layers.Flatten(),
    layers.Dense(64),
    layers.LeakyReLU(),

    layers.Dense(10)  # 10 classes
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# I0000 00:00:1774897565.605578   10247 gpu_device.cc:2043] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 8620 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:21:00.0, compute capability: 7.5

# %%
optimizer = tf.keras.optimizers.SGD(learning_rate=0.0001)

model.compile(
    optimizer=optimizer,
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy']
)

# %%
model.fit(
    x_train, y_train,
    epochs=config.epochs,
    batch_size=config.batch_size,
    validation_split=0.15,
    callbacks=[WandbMetricsLogger()]
)
# Out:
# Epoch 1/50
# I0000 00:00:1774897583.585907   10609 service.cc:153] XLA service 0x7f10d402f770 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1774897583.585941   10609 service.cc:161]   StreamExecutor [0]: NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5 (Driver: 13.0.0; Runtime: 12.3.0; Toolkit: 12.5.0; DNN: 9.19.0)
# I0000 00:00:1774897583.726336   10609 dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1774897583.791270   10609 cuda_dnn.cc:461] Loaded cuDNN version 91900
# I0000 00:00:1774897583.901050   10609 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_690__.28
#    5/1329 ━━━━━━━━━━━━━━━━━━━━ 42s 32ms/step - accuracy: 0.0972 - loss: 2.3195
# I0000 00:00:1774897589.884449   10609 device_compiler.h:208] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1324/1329 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.1233 - loss: 2.3142
# I0000 00:00:1774897605.779359   10665 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_690__.28
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 34s 20ms/step - accuracy: 0.1256 - loss: 2.3069 - val_accuracy: 0.1184 - val_loss: 2.2981
# Epoch 2/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 14s 10ms/step - accuracy: 0
50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 24s 15ms/step - accuracy: 0.3023 - loss: 1.9682 - val_accuracy: 0.2988 - val_loss: 1.9699
# Epoch 33/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 24s 17ms/step - accuracy: 0.3042 - loss: 1.9618 - val_accuracy: 0.3048 - val_loss: 1.9641
# Epoch 34/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - accuracy: 0.3070 - loss: 1.9556 - val_accuracy: 0.3071 - val_loss: 1.9579
# Epoch 35/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.3089 - loss: 1.9498 - val_accuracy: 0.3075 - val_loss: 1.9533
# Epoch 36/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 20s 11ms/step - accuracy: 0.3106 - loss: 1.9441 - val_accuracy: 0.3112 - val_loss: 1.9476
# Epoch 37/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 18s 10ms/step - accuracy: 0.3137 - loss: 1.9386 - val_accuracy: 0.3123 - val_loss: 1.9425
# Epoch 38/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 23s 12ms/step - accuracy: 0.3172 - loss: 1.9333 - val_accuracy: 0.3112 - val_loss: 1.9392
# Epoch 39/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 20s 11ms/step - accuracy: 0.3189 - loss: 1.9280 - val_accuracy: 0.3165 - val_loss: 1.9319
# Epoch 40/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 19s 10ms/step - accuracy: 0.3220 - loss: 1.9227 - val_accuracy: 0.3161 - val_loss: 1.9276
# Epoch 41/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 17s 12ms/step - accuracy: 0.3238 - loss: 1.9175 - val_accuracy: 0.3195 - val_loss: 1.9228
# Epoch 42/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 14s 10ms/step - accuracy: 0.3257 - loss: 1.9126 - val_accuracy: 0.3220 - val_loss: 1.9176
# Epoch 43/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 12s 9ms/step - accuracy: 0.3281 - loss: 1.9075 - val_accuracy: 0.3199 - val_loss: 1.9126
# Epoch 44/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 23s 11ms/step - accuracy: 0.3296 - loss: 1.9025 - val_accuracy: 0.3219 - val_loss: 1.9087
# Epoch 45/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 22s 12ms/step - accuracy: 0.3320 - loss: 1.8974 - val_accuracy: 0.3257 - val_loss: 1.9046
# Epoch 46/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 13s 10ms/step - accuracy: 0.3346 - loss: 1.8925 - val_accuracy: 0.3268 - val_loss: 1.8994
# Epoch 47/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 23s 12ms/step - accuracy: 0.3369 - loss: 1.8876 - val_accuracy: 0.3316 - val_loss: 1.8946
# Epoch 48/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 18s 10ms/step - accuracy: 0.3392 - loss: 1.8825 - val_accuracy: 0.3321 - val_loss: 1.8886
# Epoch 49/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.3411 - loss: 1.8774 - val_accuracy: 0.3353 - val_loss: 1.8842
# Epoch 50/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 19s 10ms/step - accuracy: 0.3437 - loss: 1.8723 - val_accuracy: 0.3365 - val_loss: 1.8793

# %%
score = model.evaluate(x_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.3426 - loss: 1.8729

# %%
wandb.finish()
# Out:
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch/accuracy</td><td>▁▁▁▁▂▃▃▄▄▄▅▅▅▅▅▆▆▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇█████</td></tr><tr><td>epoch/epoch</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>epoch/learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/loss</td><td>████▇▇▇▇▇▇▆▆▆▆▅▅▅▄▄▄▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▁▁▁▁▁</td></tr><tr><td>epoch/val_accuracy</td><td>▁▁▁▂▂▃▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇█▇█████</td></tr><tr><td>epoch/val_loss</td><td>█████▇▇▇▇▇▆▆▆▅▅▅▄▄▄▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch/accuracy</td><td>0.34374</td></tr><tr><td>epoch/epoch</td><td>49</td></tr><tr><td>epoch/learning_rate</td><td>0.0001</td></tr><tr><td>epoch/loss</td><td>1.87233</td></tr><tr><td>epoch/val_accuracy</td><td>0.33653</td></tr><tr><td>epoch/val_loss</td><td>1.87929</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">easy-shadow-5</strong> at: <a href='https://wandb.ai/linneaborg03-lule-university-of-technology/cnn-project/runs/97w1tll5' target="_blank">https://wandb.ai/linneaborg03-lule-university-of-technology/cnn-project/runs/97w1tll5</a><br> View project at: <a href='https://wandb.ai/linneaborg03-lule-university-of-technology/cnn-project' target="_blank">https://wandb.ai/linneaborg03-lule-university-of-technology/cnn-project</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code></code>

# %% [markdown]
# ### second version - with adam

# %%
wandb.init(
    project="cnn-project-adam",
    config={
        "epochs": 50,
        "batch_size": 32
    }
)

config = wandb.config
# Out:
# Tracking run with wandb version 0.25.1
# Run data is saved locally in <code>/wandb/run-20260330_212643-b6oaor9o</code>
# Syncing run <strong><a href='https://wandb.ai/linneaborg03-lule-university-of-technology/cnn-project-adam/runs/b6oaor9o' target="_blank">sunny-puddle-1</a></strong> to <a href='https://wandb.ai/linneaborg03-lule-university-of-technology/cnn-project-adam' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/linneaborg03-lule-university-of-technology/cnn-project-adam' target="_blank">https://wandb.ai/linneaborg03-lule-university-of-technology/cnn-project-adam</a>
#  View run at <a href='https://wandb.ai/linneaborg03-lule-university-of-technology/cnn-project-adam/runs/b6oaor9o' target="_blank">https://wandb.ai/linneaborg03-lule-university-of-technology/cnn-project-adam/runs/b6oaor9o</a>

# %%
model = models.Sequential([

    layers.Conv2D(32, (3,3), input_shape=(32,32,3)),
    layers.LeakyReLU(),
    layers.MaxPooling2D((2,2)),

    layers.Conv2D(64, (3,3)),
    layers.LeakyReLU(),
    layers.MaxPooling2D((2,2)),

    layers.Flatten(),
    layers.Dense(64),
    layers.LeakyReLU(),

    layers.Dense(10)  # 10 classes
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)

model.compile(
    optimizer=optimizer,
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy']
)

# %%
model.fit(
    x_train, y_train,
    epochs=config.epochs,
    batch_size=config.batch_size,
    validation_split=0.15,
    callbacks=[WandbMetricsLogger()]
)
# Out:
# Epoch 1/50
# I0000 00:00:1774898871.284659   10618 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_317970__.28
# 1327/1329 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.3033 - loss: 1.9545
# I0000 00:00:1774898888.761209   10662 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_317970__.28
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 28s 17ms/step - accuracy: 0.3731 - loss: 1.7771 - val_accuracy: 0.4287 - val_loss: 1.6148
# Epoch 2/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 14s 11ms/step - accuracy: 0.4740 - loss: 1.4970 - val_accuracy: 0.4923 - val_loss: 1.4403
# Epoch 3/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.5184 - loss: 1.3757 - val_accuracy: 0.5197 - val_loss: 1.3634
# Epoch 4/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 13s 9ms/step - accuracy: 0.5461 - loss: 1.2997 - val_accuracy: 0.5324 - val_loss: 1.3425
# Epoch 5/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 18s 8ms/step - accuracy: 0.5684 - loss: 1.2424 - val_accuracy: 0.5549 - val_loss: 1.2651
# Epoch 6/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 14s 10ms/step - accuracy: 0.5846 - loss: 1.2013 - val_accuracy: 0.5820 - val_loss: 1.2186
# Epoch 7/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 14s 10ms/step - accuracy: 0.5964 - loss: 1.1644 - val_accuracy: 0.5807 - val_loss: 1.2130
# Epoch 8/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 22s 12ms/step - accuracy: 0.6087 - loss: 1.1360 - val_accuracy: 0.5967 - val_loss: 1.1613
# Epoch 9/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 23s 13ms/step - accuracy: 0.6184 - loss: 1.1074 - val_accuracy: 0.6043 - val_loss: 1.1465
# Epoch 10/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.6251 - loss: 1.0832 - val_accuracy: 0.6017 - val_loss: 1.1567
# Epoch 11/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 14s 10ms/step - accuracy: 0.6335 - loss: 1.0623 - val_accuracy: 0.6151 - val_loss: 1.1131
# Epoch 12/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 25s 14ms/step - accuracy: 0.6393 - loss: 1.0427 - val_accuracy: 0.6135 - val_loss: 1.0973
# Epoch 13/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 16s 10ms/step - accuracy: 0.6475 - loss: 1.0242 - val_accuracy: 0.6257 - val_loss: 1.0903
# Epoch 14/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 21s 16ms/step - accuracy: 0.6556 - loss: 1.0047 - val_accuracy: 0.6312 - val_loss: 1.0652
# Epoch 15/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 37s 12ms/step - accuracy: 0.6573 - loss: 0.9885 - val_accuracy: 0.6271 - val_loss: 1.0838
# Epoch 16/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 20s 15ms/step - accuracy: 0.6658 - loss: 0.9719 - val_accuracy: 0.6372 - val_loss: 1.0483
# Epoch 17/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.6713 - loss: 0.9559 - val_accuracy: 0.6433 - val_loss: 1.0364
# Epoch 18/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 23s 13ms/step - accuracy: 0.6768 - loss: 0.9393 - val_accuracy: 0.6269 - val_loss: 1.1037
# Epoch 19/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 17s 10ms/step - accuracy: 0.6806 - loss: 0.9280 - val_accuracy: 0.6529 - val_loss: 1.0138
# Epoch 20/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 22s 11ms/step - accuracy: 0.6861 - loss: 0.9133 - val_accuracy: 0.6409 - val_loss: 1.0383
# Epoch 21/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 15s 11ms/step - accuracy: 0.6922 - loss: 0.8994 - val_accuracy: 0.6541 - val_loss: 1.0082
# Epoch 22/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 14s 10ms/step - accuracy: 0.6935 - loss: 0.8908 - val_accuracy: 0.6559 - val_loss: 0.9918
# Epoch 23/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 16s 12ms/step - accuracy: 0.7008 - loss: 0.8765 - val_accuracy: 0.6561 - val_loss: 0.9927
# Epoch 24/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 21s 12ms/step
�▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/val_accuracy</td><td>▁▃▃▄▄▅▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇█▇█▇████████████</td></tr><tr><td>epoch/val_loss</td><td>█▆▅▅▄▄▃▃▃▃▃▂▂▂▂▂▂▂▂▂▁▂▂▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch/accuracy</td><td>0.78864</td></tr><tr><td>epoch/epoch</td><td>49</td></tr><tr><td>epoch/learning_rate</td><td>0.0001</td></tr><tr><td>epoch/loss</td><td>0.62989</td></tr><tr><td>epoch/val_accuracy</td><td>0.68267</td></tr><tr><td>epoch/val_loss</td><td>0.96835</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">sunny-puddle-1</strong> at: <a href='https://wandb.ai/linneaborg03-lule-university-of-technology/cnn-project-adam/runs/b6oaor9o' target="_blank">https://wandb.ai/linneaborg03-lule-university-of-technology/cnn-project-adam/runs/b6oaor9o</a><br> View project at: <a href='https://wandb.ai/linneaborg03-lule-university-of-technology/cnn-project-adam' target="_blank">https://wandb.ai/linneaborg03-lule-university-of-technology/cnn-project-adam</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code></code>

# %% [markdown]
# ### third version - with tanh

# %%
wandb.init(
    project="cnn-project-tanh",
    config={
        "epochs": 50,
        "batch_size": 32
    }
)

config = wandb.config
# Out:
# Tracking run with wandb version 0.25.1
# Run data is saved locally in <code>/wandb/run-20260330_230603-62eoituu</code>
# Syncing run <strong><a href='https://wandb.ai/linneaborg03-lule-university-of-technology/cnn-project-tanh/runs/62eoituu' target="_blank">distinctive-oath-1</a></strong> to <a href='https://wandb.ai/linneaborg03-lule-university-of-technology/cnn-project-tanh' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/linneaborg03-lule-university-of-technology/cnn-project-tanh' target="_blank">https://wandb.ai/linneaborg03-lule-university-of-technology/cnn-project-tanh</a>
#  View run at <a href='https://wandb.ai/linneaborg03-lule-university-of-technology/cnn-project-tanh/runs/62eoituu' target="_blank">https://wandb.ai/linneaborg03-lule-university-of-technology/cnn-project-tanh/runs/62eoituu</a>

# %%
# Model
model = models.Sequential([

    layers.Conv2D(32, (3,3), input_shape=(32,32,3)),
    layers.Activation('tanh'),
    layers.MaxPooling2D((2,2)),

    layers.Conv2D(64, (3,3)),
    layers.Activation('tanh'),
    layers.MaxPooling2D((2,2)),

    layers.Flatten(),
    layers.Dense(64),
    layers.Activation('tanh'),

    layers.Dense(10)
])

# Optimizer Adam
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy']
)

model.fit(
    x_train, y_train,
    epochs=config.epochs,
    batch_size=config.batch_size,
    validation_split=0.15,
    callbacks=[WandbMetricsLogger()]
)
# Out:
# Epoch 1/50
# I0000 00:00:1774907828.967544   10609 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_951276__.28
# 1326/1329 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.4197 - loss: 1.6260
# I0000 00:00:1774907862.611739   10609 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_951276__.28
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 48s 33ms/step - accuracy: 0.4974 - loss: 1.4182 - val_accuracy: 0.5764 - val_loss: 1.2053
# Epoch 2/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 72s 28ms/step - accuracy: 0.6118 - loss: 1.1058 - val_accuracy: 0.6245 - val_loss: 1.0806
# Epoch 3/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 31s 23ms/step - accuracy: 0.6592 - loss: 0.9830 - val_accuracy: 0.6367 - val_loss: 1.0528
# Epoch 4/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 23s 17ms/step - accuracy: 0.6893 - loss: 0.8955 - val_accuracy: 0.6477 - val_loss: 1.0107
# Epoch 5/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 30s 22ms/step - accuracy: 0.7197 - loss: 0.8090 - val_accuracy: 0.6499 - val_loss: 1.0222
# Epoch 6/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 56s 33ms/step - accuracy: 0.7448 - loss: 0.7416 - val_accuracy: 0.6565 - val_loss: 1.0165
# Epoch 7/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 25s 19ms/step - accuracy: 0.7683 - loss: 0.6731 - val_accuracy: 0.6567 - val_loss: 1.0300
# Epoch 8/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 31s 11ms/step - accuracy: 0.7931 - loss: 0.6066 - val_accuracy: 0.6499 - val_loss: 1.0698
# Epoch 9/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 38s 28ms/step - accuracy: 0.8129 - loss: 0.5500 - val_accuracy: 0.6501 - val_loss: 1.0824
# Epoch 10/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 24s 16ms/step - accuracy: 0.8317 - loss: 0.4937 - val_accuracy: 0.6463 - val_loss: 1.1410
# Epoch 11/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 46s 20ms/step - accuracy: 0.8523 - loss: 0.4423 - val_accuracy: 0.6503 - val_loss: 1.1835
# Epoch 12/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━
50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 45s 34ms/step - accuracy: 0.9653 - loss: 0.1018 - val_accuracy: 0.6168 - val_loss: 2.2301
# Epoch 39/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 83s 34ms/step - accuracy: 0.9645 - loss: 0.1058 - val_accuracy: 0.6211 - val_loss: 2.2342
# Epoch 40/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 24s 18ms/step - accuracy: 0.9649 - loss: 0.1042 - val_accuracy: 0.6205 - val_loss: 2.3023
# Epoch 41/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 45s 34ms/step - accuracy: 0.9639 - loss: 0.1053 - val_accuracy: 0.6128 - val_loss: 2.3588
# Epoch 42/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 39s 29ms/step - accuracy: 0.9612 - loss: 0.1132 - val_accuracy: 0.6181 - val_loss: 2.2395
# Epoch 43/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 27s 20ms/step - accuracy: 0.9728 - loss: 0.0822 - val_accuracy: 0.6187 - val_loss: 2.3011
# Epoch 44/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 30s 23ms/step - accuracy: 0.9652 - loss: 0.1022 - val_accuracy: 0.6171 - val_loss: 2.3053
# Epoch 45/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 30s 22ms/step - accuracy: 0.9677 - loss: 0.0954 - val_accuracy: 0.6153 - val_loss: 2.3506
# Epoch 46/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 53s 31ms/step - accuracy: 0.9665 - loss: 0.0956 - val_accuracy: 0.6167 - val_loss: 2.3626
# Epoch 47/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 68s 21ms/step - accuracy: 0.9639 - loss: 0.1042 - val_accuracy: 0.6155 - val_loss: 2.4232
# Epoch 48/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 28s 21ms/step - accuracy: 0.9644 - loss: 0.1042 - val_accuracy: 0.6193 - val_loss: 2.3873
# Epoch 49/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 35s 26ms/step - accuracy: 0.9674 - loss: 0.0958 - val_accuracy: 0.6044 - val_loss: 2.4543
# Epoch 50/50
# 1329/1329 ━━━━━━━━━━━━━━━━━━━━ 45s 29ms/step - accuracy: 0.9657 - loss: 0.1000 - val_accuracy: 0.6191 - val_loss: 2.3693

# %%
score = model.evaluate(x_test, y_test)
wandb.finish()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.6145 - loss: 2.3919
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch/accuracy</td><td>▁▃▄▄▅▅▆▆▇▇█████████████▃▄▇▇▇▇███████████</td></tr><tr><td>epoch/epoch</td><td>▁▁▂▃▃▃▄▄▄▅▆▆▆▆▇▇▇█▁▁▂▂▂▂▂▃▃▄▄▅▅▅▅▆▆▆▆▇▇█</td></tr><tr><td>epoch/learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/loss</td><td>█▆▆▄▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▆▆▃▃▂▂▂▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/val_accuracy</td><td>▇▇██▆▅▅▅▅▄▂▃▃▄▃▂▃▂▂▄█▇▇▇▇▅▆▄▄▄▃▃▃▃▃▃▃▂▃▁</td></tr><tr><td>epoch/val_loss</td><td>▂▁▁▁▁▃▃▃▄▄▅▅▅▆▇▇▇███▂▁▁▁▁▂▂▂▃▃▄▅▅▆▆▇▇▇▇▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch/accuracy</td><td>0.96567</td></tr><tr><td>epoch/epoch</td><td>49</td></tr><tr><td>epoch/learning_rate</td><td>0.001</td></tr><tr><td>epoch/loss</td><td>0.1</td></tr><tr><td>epoch/val_accuracy</td><td>0.61907</td></tr><tr><td>epoch/val_loss</td><td>2.36925</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">distinctive-oath-1</strong> at: <a href='https://wandb.ai/linneaborg03-lule-university-of-technology/cnn-project-tanh/runs/62eoituu' target="_blank">https://wandb.ai/linneaborg03-lule-university-of-technology/cnn-project-tanh/runs/62eoituu</a><br> View project at: <a href='https://wandb.ai/linneaborg03-lule-university-of-technology/cnn-project-tanh' target="_blank">https://wandb.ai/linneaborg03-lule-university-of-technology/cnn-project-tanh</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code></code>

# %% [markdown]
# ## Results

# %%
#test_loss, test_acc = model.evaluate(x_test, y_test)
#print("Accuracy sur test set :", test_acc)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 1.8535 - accuracy: 0.3498
# Accuracy sur test set : 0.3497999906539917
